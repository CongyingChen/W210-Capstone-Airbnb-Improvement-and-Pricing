# %%
import pandas as pd
import pygeoj

# %%
reviews = pd.read_csv('/Users/charlenechen/Desktop/reviews.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
reviews.head()
# Out:
#    listing_id     id        date  reviewer_id reviewer_name  \
# 0         958   5977  2009-07-23        15695      Edmund C
# 1         958   6660  2009-08-03        26145         Simon
# 2         958  11519  2009-09-27        25839         Denis
# 3         958  16282  2009-11-05        33750          Anna
# 4         958  26008  2010-02-13        15416       Venetia
#
#                                             comments
# 0  Our experience was, without a doubt, a five st...
# 1  Returning to San Francisco is a rejuvenating t...
# 2  We were very pleased with the accommodations a...
# 3  We highly recommend this accomodation and agre...
# 4  Holly's place was great. It was exactly what I...

# %%
listings = pd.read_csv('/Users/charlenechen/Desktop/listings.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
listings.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   958   https://www.airbnb.com/rooms/958  20190503153007   2019-05-03
# 1  5858  https://www.airbnb.com/rooms/5858  20190503153007   2019-05-03
# 2  7918  https://www.airbnb.com/rooms/7918  20190503153007   2019-05-03
# 3  8142  https://www.airbnb.com/rooms/8142  20190503153007   2019-05-03
# 4  8339  https://www.airbnb.com/rooms/8339  20190503153007   2019-05-03
#
#                                                 name  \
# 0                Bright, Modern Garden Unit - 1BR/1B
# 1                                 Creative Sanctuary
# 2         A Friendly Room - UCSF/USF - San Francisco
# 3  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 4                    Historic Alamo Square Victorian
#
#                                              summary  \
# 0  New update: the house next door is under const...
# 1                                                NaN
# ...

# %%
calendar = pd.read_csv('/Users/charlenechen/Desktop/calendar.csv.gz', nrows=100, compression='gzip',
                   error_bad_lines=False)
calendar.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0    34158472  2019-05-03         f  $399.00        $399.00               2
# 1    34158472  2019-05-04         f  $399.00        $399.00               2
# 2    34158472  2019-05-05         t  $399.00        $399.00               2
# 3    34158472  2019-05-06         t  $399.00        $399.00               2
# 4    34158472  2019-05-07         t  $399.00        $399.00               2
#
#    maximum_nights
# 0            1125
# 1            1125
# 2            1125
# 3            1125
# 4            1125

# %%
neighbourhoods = pygeoj.load("/Users/charlenechen/Desktop/neighbourhoods.geojson")
#testfile
#for feature in testfile:
#    print (feature.geometry)
    #print (feature.geometry.coordinates)

# %% [markdown]
# ## Plot Geojason file
# https://stackoverflow.com/questions/50192549/display-in-geojsonio-gives-401-error

# %%
import geopandas as gpd
states = gpd.read_file('/Users/charlenechen/Desktop/neighbourhoods.geojson')
print(states.head())
states = states.to_json()
#print(states)
import geojsonio
geojsonio.display(states)
# Out:
#            neighbourhood neighbourhood_group  \
# 0               Seacliff                None
# 1         Haight Ashbury                None
# 2          Outer Mission                None
# 3  Downtown/Civic Center                None
# 4        Diamond Heights                None
#
#                                             geometry
# 0  (POLYGON ((-122.484089 37.78791, -122.484346 3...
# 1  (POLYGON ((-122.435964 37.769038, -122.436851 ...
# 2  (POLYGON ((-122.454284 37.708222, -122.45456 3...
# 3  (POLYGON ((-122.408912 37.790132, -122.408797 ...
# 4  (POLYGON ((-122.435527 37.74146, -122.435632 3...
# 'http://geojson.io/#id=gist:/d235c6681a84359dd4eeeac2c79f9fdf'

# %%
NY = gpd.read_file('/Users/charlenechen/Desktop/neighbourhoods-NY.geojson')
NY = NY.to_json()
#print(states)
import geojsonio
geojsonio.display(NY)
# Out:
# 'http://geojson.io/#id=gist:/90a7c7310b3bfa73327746952e8c050a'
